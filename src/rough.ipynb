# %%
import re

# %%
with open(r'/Users/outbell/Ajay/DeepLearning/GenAI/smallGPT/data/shakesphere.txt', 'r') as f:
    data = f.read()

processed_data = re.findall(r'\S+,?\s+|\S+,|\S+\s+', data)

# %%
for i in range(10):
    print(chr(i))

# %%
encoded_data = []
for word in processed_data:
    encoded_data.append(list(word.encode('utf-8')))

# %%
encoded_data[:10]

# %%
encoded_data[0]
# Out:
# [70, 105, 114, 115, 116, 32]

# %%
def get_batch(mode):
    if mode == 'train':
        x, y = xtr, ytr
    else:
        x, y = xval, yval

    ix = [random.randint(0, len(x)) for _ in range(config.batch_size)]
    xb = pad([x[i] for i in ix])
    yb = pad([y[i] for i in ix])

# %%
for word in encoded_data[:10]:
    ls = []
    for ch in word:
        ls.append(chr(ch))
    print(''.join(ls), end = '')
ls
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
# ['s', 'p', 'e', 'a', 'k', '.', '\n', '\n']

# %%
processed_data = {line : len(line) for line in processed_data}

# %%
sorted_processed_data = dict(sorted(processed_data.items(), key=lambda item: item[1], reverse=True))

# %%
sorted_processed_data
# Out:
# {'princess,--goddess!--O, ': 24,
#  'senseless--obstinate, ': 22,
#  'fellow-school-master\n': 21,
#  "ten-times-barr'd-up ": 20,
#  'waiting-gentlewoman ': 20,
#  'serving-creature.\n\n': 19,
#  "serving-creature's ": 19,
#  'three-man-song-men ': 19,
#  'promise-breaker.\n\n': 18,
#  'gallant-springing ': 18,
#  'attorneys-general ': 18,
#  'neighbour-stained ': 18,
#  'slander,--Tybalt, ': 18,
#  "Romeo--banished;'\n": 18,
#  'pomegranate-tree:\n': 18,
#  'parliament-house!\n': 18,
#  'great-grandfather ': 18,
#  'chamber-councils, ': 18,
#  'wilful-negligent,\n': 18,
#  'three-and-twenty, ': 18,
#  'behind-door-work: ': 18,
#  'promise-keeping.\n\n': 18,
#  'shoulder-shotten;\n': 18,
#  "mean-apparell'd.\n\n": 18,
#  'up-staring,--then ': 18,
#  'them,--Ding-dong, ': 18,
#  'soft-conscienced ': 17,
#  'nobler,--whither ': 17,
#  'weakness,--thine ': 17,
#  'particular,--you ': 17,
#  'breathing-while,\n': 17,
#  'childish-foolish ': 17,
#  'slaughter-house.\n': 17,
# ...
